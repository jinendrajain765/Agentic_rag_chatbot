# %%
n=(1,2,3,4,5,6,1,2,6)
m=len(n)
dict={}

for i in range(0,m):
    dict[n[i]]=dict.get(n[i],0)+1 # iska matlab hai dek ye dict me value store karne ke kam ati hai  dict get matlab hame item do agar rahega to dedega agar nahi rahega to 0 or +1 islia hai agar nahi rahega to 0 ho jaiga get item or 1 means wo item add ho jaiga with frequency 1 agar key rahegi to value return kr dega nahi wo value add ho jaiga with frequency abb add hoga to uski frequency 1 hogi an 

print(dict.items())

# DSA Python Course 2025 - Store Frequency in Dictionary - Part 10 [Hindi] | Code & Debug
# Out:
# dict_items([(1, 2), (2, 2), (3, 1), (4, 1), (5, 1), (6, 2)])
